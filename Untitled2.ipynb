# %%
import numpy as np
from BioImage import BioImage, folders
from numpy.random import randint
from tqdm import tqdm,trange
import matplotlib.pyplot as plt

folder = 0
sample = 6520

b = BioImage(folders[folder], sample)
b.showPipeline()

mask = b.getThresholded(b.ch3)
# plt.imshow(mask)

# %%
import numpy as np
from BioImage import BioImage, folders
from numpy.random import randint
from tqdm import tqdm,trange

folder = 0
sample = 6525

b = BioImage(folders[folder], sample)
b.showPipeline()
